# %% [markdown]
# ## Importing Stuffs

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic Graph

# %%
fig, axs = plt.subplots()  # Create a figure containing a single axes.
axs.plot([1, 2, 3, 4], [2, 4, 9, 16])  # Plot some data on the axes.

# %%
df = pd.DataFrame({
    "Marks": [89,34,45,67,29],
}, index=["Jack","Jhon","James","Rocky","Roy"])
df
# Out:
#        Marks
# Jack      89
# Jhon      34
# James     45
# Rocky     67
# Roy       29

# %%
df.plot.barh()
# Out:
# <Axes: >
